# %% [markdown]
# # 1. Uploading required libraries and COVID-19 Coronavirus data set.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
df=pd.read_csv(r'C:\Users\Welcome\Desktop\Data Science Internship\CSV FILES\COVID-19 Coronavirus.csv')
df
# Out:
#                Country                Other names ISO 3166-1 alpha-3 CODE  \
# 0          Afghanistan                Afghanistan                     AFG
# 1              Albania                    Albania                     ALB
# 2              Algeria                    Algeria                     DZA
# 3              Andorra                    Andorra                     AND
# 4               Angola                     Angola                     AGO
# ..                 ...                        ...                     ...
# 220  Wallis and Futuna  Wallis and Futuna Islands                     WLF
# 221     Western Sahara             Western Sahara                   ESHÂ
# 222              Yemen                      Yemen                     YEM
# 223             Zambia                     Zambia                     ZMB
# 224           Zimbabwe                   Zimbabwe                     ZWE
#
#      Population Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# ...

# %% [markdown]
# # 2. Check the shape

# %%
df.shape
# Out:
# (225, 10)

# %% [markdown]
# # 3. Check head

# %%
df.head(30)
# Out:
#                    Country                       Other names  \
# 0              Afghanistan                       Afghanistan
# 1                  Albania                           Albania
# 2                  Algeria                           Algeria
# 3                  Andorra                           Andorra
# 4                   Angola                            Angola
# 5                 Anguilla                          Anguilla
# 6      Antigua and Barbuda               Antigua and Barbuda
# 7                Argentina                         Argentina
# 8                  Armenia                           Armenia
# 9                    Aruba                             Aruba
# 10               Australia                         Australia
# 11                 Austria                           Austria
# 12              Azerbaijan                        Azerbaijan
# 13                 Bahamas                           Bahamas
# ...

# %% [markdown]
# # 4. Check tail

# %%
df.tail(30)
# Out:
#                  Country                                        Other names  \
# 195               Sweden                                             Sweden
# 196          Switzerland                                        Switzerland
# 197                Syria                               Syrian Arab Republic
# 198               Taiwan                    China, Taiwan Province of China
# 199           Tajikistan                                         Tajikistan
# 200             Tanzania                        United Republic of Tanzania
# 201             Thailand                                           Thailand
# 202          Timor-Leste                                        Timor-Leste
# 203                 Togo                                               Togo
# 204                Tonga                                              Tonga
# 205  Trinidad and Tobago                                Trinidad and Tobago
# ...

# %% [markdown]
# # 5. Check info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  225 non-null    object
#  1   Other names              224 non-null    object
#  2   ISO 3166-1 alpha-3 CODE  225 non-null    object
#  3   Population               225 non-null    int64
#  4   Continent                225 non-null    object
#  5   Total Cases              225 non-null    int64
#  6   Total Deaths             225 non-null    int64
#  7   Tot Cases//1M pop        225 non-null    int64
#  8   Tot Deaths/1M pop        225 non-null    int64
#  9   Death percentage         225 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 17.7+ KB

# %% [markdown]
# # 6. Check missing values

# %%
df.isnull().sum()
# Out:
# Country                    0
# Other names                1
# ISO 3166-1 alpha-3 CODE    0
# Population                 0
# Continent                  0
# Total Cases                0
# Total Deaths               0
# Tot Cases//1M pop          0
# Tot Deaths/1M pop          0
# Death percentage           0
# dtype: int64

# %%
df.notnull()
# Out:
#      Country  Other names  ISO 3166-1 alpha-3 CODE  Population  Continent  \
# 0       True         True                     True        True       True
# 1       True         True                     True        True       True
# 2       True         True                     True        True       True
# 3       True         True                     True        True       True
# 4       True         True                     True        True       True
# ..       ...          ...                      ...         ...        ...
# 220     True         True                     True        True       True
# 221     True         True                     True        True       True
# 222     True         True                     True        True       True
# 223     True         True                     True        True       True
# 224     True         True                     True        True       True
#
#      Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# ...

# %% [markdown]
# # 7.	Rows which contains null values

# %%
df[df.isnull().any(axis=1)]
# Out:
#         Country Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 135  Montenegro         NaN                     MNE      628205    Europe
#
#      Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 135       233326          2705             371417               4306
#
#      Death percentage
# 135          1.159322

# %% [markdown]
# # 8.	Fill null value with most suitable value (hint to replace,use inplace=True)
#  (replacing Nan with Montenegro)

# %%
df.fillna("Montenegro", inplace=True)

# %% [markdown]
# # 9.	Sanity check weather null values are replaced or not
#  (checking weather it is replaced or not)

# %%
df.loc[135]
# Out:
# Country                    Montenegro
# Other names                Montenegro
# ISO 3166-1 alpha-3 CODE           MNE
# Population                     628205
# Continent                      Europe
# Total Cases                    233326
# Total Deaths                     2705
# Tot Cases//1M pop              371417
# Tot Deaths/1M pop                4306
# Death percentage             1.159322
# Name: 135, dtype: object

# %% [markdown]
# # 	10.	Check stats information of data set.

# %%
df.describe()
# Out:
#          Population   Total Cases  Total Deaths  Tot Cases//1M pop  \
# count  2.250000e+02  2.250000e+02  2.250000e+02         225.000000
# mean   3.507321e+07  2.184781e+06  2.744813e+04      136900.373333
# std    1.392418e+08  7.275938e+06  9.689177e+04      145060.340289
# min    8.050000e+02  1.000000e+00  0.000000e+00           9.000000
# 25%    5.665570e+05  2.407100e+04  1.890000e+02       11384.000000
# 50%    5.827911e+06  1.639360e+05  1.965000e+03       88987.000000
# 75%    2.190585e+07  1.092547e+06  1.366000e+04      223335.000000
# max    1.439324e+09  8.183905e+07  1.008222e+06      696044.000000
#
#        Tot Deaths/1M pop  Death percentage
# count         225.000000        225.000000
# mean         1096.715556          1.444125
# std          1195.715543          1.741728
# min             0.000000          0.000000
# 25%           123.000000          0.511291
# 50%           708.000000          1.036905
# 75%          1795.000000          1.977017
# ...

# %% [markdown]
# # 11.	Top 5 countries which have more number of covid cases (hint use df.nlargest)

# %%
top_5=df.nlargest(5,'Total Cases')['Country']
top_5
# Out:
# 214        USA
# 92       India
# 26      Brazil
# 70      France
# 76     Germany
# Name: Country, dtype: object

# %%
top_5=df.nlargest(n=5,columns='Total Cases')
top_5
# Out:
#      Country               Other names ISO 3166-1 alpha-3 CODE  Population  \
# 214      USA  United States of America                     USA   334400597
# 92     India                     India                     IND  1403754381
# 26    Brazil                    Brazil                     BRA   215204501
# 70    France                    France                     FRA    65526369
# 76   Germany                   Germany                     DEU    84252947
#
#                            Continent  Total Cases  Total Deaths  \
# 214                 Northern America     81839052       1008222
# 92                              Asia     43029044        521388
# 26   Latin America and the Caribbean     29999816        660269
# 70                            Europe     25997852        142506
# 76                            Europe     21646375        130563
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 214             244734               3015          1.231957
# ...

# %% [markdown]
# # 12.	Plot bar graph for top 5 countries

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=top_5 ,y="Total Cases", x="Country")
plt.title("Top 5 countries VS Covid cases")
plt.xlabel("Countries")
plt.ylabel("Covid cases")


plt.show()

# %% [markdown]
# # 13.	Least 5 countries which have least number of covid cases

# %%
least_5=df.nsmallest(5,'Total Cases')['Country']
least_5
# Out:
# 131          Micronesia
# 168        Saint Helena
# 125    Marshall Islands
# 148                Niue
# 221      Western Sahara
# Name: Country, dtype: object

# %%
least_5=df.nsmallest(n=5,columns='Total Cases')
least_5
# Out:
#               Country                       Other names  \
# 131        Micronesia  Micronesia (Federated States of)
# 168      Saint Helena                      Saint Helena
# 125  Marshall Islands                  Marshall Islands
# 148              Niue                              Niue
# 221    Western Sahara                    Western Sahara
#
#     ISO 3166-1 alpha-3 CODE  Population Continent  Total Cases  Total Deaths  \
# 131                     FSM      117134   Oceania            1             0
# 168                     SHN        6109    Africa            2             0
# 125                     MHL       59889   Oceania            7             0
# 148                     NIU        1645   Oceania            7             0
# 221                   ESHÂ       623031    Africa           10             1
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 131                  9                  0               0.0
# ...

# %% [markdown]
# # 14.	Draw bar graph of least 5 countries

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=least_5 ,y="Total Cases", x="Country")
plt.title("Least 5 countries VS Covid cases")
plt.xlabel("Countries")
plt.ylabel("Covid cases")


plt.show()

# %% [markdown]
# # 15.	Top 5 countries which have more number of covid Deaths

# %%
top_5=df.nlargest(5,'Total Deaths')['Country']
top_5
# Out:
# 214       USA
# 26     Brazil
# 92      India
# 165    Russia
# 130    Mexico
# Name: Country, dtype: object

# %%
top_5=df.nlargest(n=5,columns='Total Deaths')
top_5
# Out:
#     Country               Other names ISO 3166-1 alpha-3 CODE  Population  \
# 214     USA  United States of America                     USA   334400597
# 26   Brazil                    Brazil                     BRA   215204501
# 92    India                     India                     IND  1403754381
# 165  Russia        Russian Federation                     RUS   146044010
# 130  Mexico                    Mexico                     MEX   131303955
#
#                            Continent  Total Cases  Total Deaths  \
# 214                 Northern America     81839052       1008222
# 26   Latin America and the Caribbean     29999816        660269
# 92                              Asia     43029044        521388
# 165                           Europe     17896866        369708
# 130  Latin America and the Caribbean      5665376        323212
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 214             244734               3015          1.231957
# ...

# %% [markdown]
# # 16. Plot bar graph for top 5 countries which have more number of covid Deaths

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=top_5 ,y="Total Deaths", x="Country")
plt.title("Top5 countries VS Covid deaths")
plt.xlabel("Countries")
plt.ylabel("Covid Deaths")


plt.show()

# %% [markdown]
# # 17.	Countries which have least number of covid Death

# %%
least_5=df.nsmallest(5,'Total Deaths')['Country']
least_5
# Out:
# 46         Cook Islands
# 67     Falkland Islands
# 118               Macao
# 125    Marshall Islands
# 131          Micronesia
# Name: Country, dtype: object

# %%
least_5=df.nsmallest(n=5,columns='Total Deaths')
least_5
# Out:
#               Country                                 Other names  \
# 46       Cook Islands                                Cook Islands
# 67   Falkland Islands                 Falkland Islands (Malvinas)
# 118             Macao  China, Macao Special Administrative Region
# 125  Marshall Islands                            Marshall Islands
# 131        Micronesia            Micronesia (Federated States of)
#
#     ISO 3166-1 alpha-3 CODE  Population                        Continent  \
# 46                      COK       17592                          Oceania
# 67                      FLK        3657  Latin America and the Caribbean
# 118                     MAC      664828                             Asia
# 125                     MHL       59889                          Oceania
# 131                     FSM      117134                          Oceania
#
#      Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# ...

# %% [markdown]
# # 18. Plot bar graph for least 5 countries which have least number of covid Deaths

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=least_5 ,y="Total Deaths", x="Country")
plt.title("Least 5 countries VS Covid deaths")
plt.xlabel("Countries")
plt.ylabel("Covid deaths")


plt.show()

# %% [markdown]
# # 19.	Top 5 countries which have more number of covid  Death percentage

# %%
top_5_countries=df.nlargest(5,'Death percentage')['Country']
top_5_countries
# Out:
# 222             Yemen
# 221    Western Sahara
# 193             Sudan
# 158              Peru
# 130            Mexico
# Name: Country, dtype: object

# %%
top_5_countries=df.nlargest(n=5,columns='Death percentage')
top_5_countries
# Out:
#             Country     Other names ISO 3166-1 alpha-3 CODE  Population  \
# 222           Yemen           Yemen                     YEM    30975258
# 221  Western Sahara  Western Sahara                   ESHÂ       623031
# 193           Sudan           Sudan                     SDN    45640385
# 158            Peru            Peru                     PER    33775745
# 130          Mexico          Mexico                     MEX   131303955
#
#                            Continent  Total Cases  Total Deaths  \
# 222                             Asia        11806          2143
# 221                           Africa           10             1
# 193                           Africa        61955          4907
# 158  Latin America and the Caribbean      3548559        212328
# 130  Latin America and the Caribbean      5665376        323212
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 222                381                 69         18.151787
# ...

# %% [markdown]
# # 20. Plot bar graph for top 5 countries which have more number of covid Death percentage

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=top_5_countries,y="Death percentage", x="Country")
plt.title("Top 5 countries VS Death Percentage")
plt.xlabel("Countries")
plt.ylabel("Death percentage")


plt.show()

# %% [markdown]
# # 21 .Continent wise cases for top 5 countries (hint use group by)

# %%
case_continent=df.groupby("Continent").sum()
case_continent
# Out:
#                                                                            Country  \
# Continent
# Africa                           AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...
# Asia                             AfghanistanArmeniaAzerbaijanBahrainBangladeshB...
# Europe                           AlbaniaAndorraAustriaBelarusBelgiumBosnia and ...
# Latin America and the Caribbean  AnguillaAntigua and BarbudaArgentinaArubaBaham...
# Northern America                    BermudaCanadaGreenlandSaint Pierre MiquelonUSA
# Oceania                          AustraliaCook IslandsFijiFrench PolynesiaKirib...
#
#                                                                        Other names  \
# Continent
# Africa                           AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...
# Asia                             AfghanistanArmeniaAzerbaijanBahrainBangladeshB...
# Europe                           AlbaniaAndorraAustriaBelarusBelgiumBosnia and ...
# ...

# %% [markdown]
# # 22. Draw bar plot for continent wise case

# %%
case_continent=case_continent.reset_index()
plt.figure(figsize=(16,8))
sns.barplot(data=case_continent,y="Total Cases", x="Continent")
plt.xlabel("Top 5 Continents")
plt.ylabel("Covid Cases")


plt.show()

# %% [markdown]
# # 23.	Find relationship between Population and total cases

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(y=df['Total Cases'], x=df['Population'])
plt.xlabel("Population")
plt.ylabel("Covid Cases")
plt.title("Scatter plot between population and Total cases")


plt.show()

# %% [markdown]
# # 24. Spearman rank correlation heatmap

# %%
numeric_df=df.select_dtypes(include='number')
heatmap=sns.heatmap(numeric_df.corr(method='spearman').round(3), vmin=-1, vmax=1, annot=True)
